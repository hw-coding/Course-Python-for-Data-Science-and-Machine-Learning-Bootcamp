# %% [markdown]
# # DATA

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # Exercises 1

# %% [markdown]
# ** Follow along with these steps: **
#
# ** Create a figure object called fig using plt.figure() **
# ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('title')
#plt.plot(x,y)
# Out:
# Text(0.5,1,'title')

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

ax1.plot(x,y,'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax2.plot(x,y,'b')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4])

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.4,0.4])
ax1.plot(x,z)
ax2.plot(x,y)

fig2 = plt.figure()
ax3 = fig2.add_axes([0,0,1,1])
ax4 = fig2.add_axes([0.2,0.5,0.4,0.4])
ax3.plot(x,z)
ax4.plot(x,y)

# %%
fig,(ax1, ax2) = plt.subplots(nrows=2,ncols=1)
#fig, (ax, ax2) = plt.subplots(1, 2)
#ax1 = fig.add_axes([0,0,1,1])
#ax2 = fig.add_axes([0.2,0.5,0.4,0.4])

ax1.set_position([0,0,1,1])
ax12=fig.add_axes([0.2,0.5,0.4,0.4])



ax2.set_position([0,1.2,1,1])
ax22=fig.add_axes([0.2,1.2+0.5,0.4,0.4])

ax1.plot(x,z)
ax12.plot(x,y)
ax2.plot(x,z)
ax22.plot(x,y)

# ax2.set_xlim([20,22])
# ax2.set_ylim([30,50])

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,ax = plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig,ax = plt.subplots(nrows=1,ncols=2)
ax[0].plot(x,y,color='blue',lw=3,linestyle='--')
ax[1].plot(x,z,color='red',lw=3,linestyle='-')

plt.tight_layout()

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=[8, 2])
ax[0].plot(x,y,color='blue',lw=3,linestyle='-')
ax[1].plot(x,z,color='red',lw=5,linestyle='--')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')

ax[1].set_xlabel('x')
ax[1].set_ylabel('y')
plt.tight_layout()
